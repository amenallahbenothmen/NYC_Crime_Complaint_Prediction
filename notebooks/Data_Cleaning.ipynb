# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("NYPD_Complaint_Data_Historic.csv")
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\2830271546.py:1: DtypeWarning: Columns (18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("NYPD_Complaint_Data_Historic.csv")

# %%
df.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   700381962   05/28/2015     15:00:00          NaN          NaN
# 1   642234217   10/28/2013     13:50:00   10/28/2013     13:50:00
# 2   242465164   05/09/2012     20:50:00   05/09/2012     21:00:00
# 3   927207428   01/03/2014     13:30:00   01/03/2014     13:35:00
# 4   492142357   04/13/2016     00:00:00          NaN          NaN
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  ...  \
# 0         46.0  06/01/2015    578                   HARRASSMENT 2  638.0  ...
# 1        120.0  10/28/2013    351  CRIMINAL MISCHIEF & RELATED OF  259.0  ...
# 2         24.0  05/09/2012    236               DANGEROUS WEAPONS  782.0  ...
# 3        108.0  01/03/2014    109                   GRAND LARCENY  409.0  ...
# 4         40.0  04/13/2016    351  CRIMINAL MISCHIEF & RELATED OF  258.0  ...
#
#   SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# 0        M              NaN  40.845868 -73.915888
# 1      NaN              NaN  40.627061 -74.077149
# 2      NaN              NaN  40.800966 -73.969047
# 3        M              NaN  40.745242 -73.894253
# 4      NaN              NaN  40.810352 -73.924942
#
#                          Lat_Lon                PATROL_BORO STATION_NAME  \
# 0   (40.84586773, -73.915888033)          PATROL BORO BRONX          NaN
# 1  (40.627060894, -74.077149232)  PATROL BORO STATEN ISLAND          NaN
# 2  (40.800965968, -73.969047272)      PATROL BORO MAN NORTH          NaN
# 3  (40.745241809, -73.894253382)   PATROL BORO QUEENS NORTH          NaN
# 4  (40.810351863, -73.924942326)          PATROL BORO BRONX          NaN
#
#    VIC_AGE_GROUP                  VIC_RACE VIC_SEX
# 0          25-44            WHITE HISPANIC       F
# 1          45-64                     WHITE       M
# 2            NaN                   UNKNOWN       E
# 3          45-64  ASIAN / PACIFIC ISLANDER       M
# 4        UNKNOWN                   UNKNOWN       E
#
# [5 rows x 35 columns]

# %%
df.describe()
# Out:
#          CMPLNT_NUM   ADDR_PCT_CD         KY_CD         PD_CD  \
# count  6.983207e+06  6.981041e+06  6.983207e+06  6.977342e+06
# mean   5.500768e+08  6.327224e+01  2.957909e+02  4.148457e+02
# std    2.597838e+08  3.451961e+01  1.499370e+02  2.180586e+02
# min    1.000001e+08 -9.900000e+01  1.010000e+02  1.000000e+02
# 25%    3.252107e+08  4.000000e+01  1.170000e+02  2.540000e+02
# 50%    5.500624e+08  6.300000e+01  3.410000e+02  3.860000e+02
# 75%    7.750561e+08  9.400000e+01  3.510000e+02  6.370000e+02
# max    9.999999e+08  1.230000e+02  8.810000e+02  9.750000e+02
#
#        JURISDICTION_CODE    X_COORD_CD    Y_COORD_CD  TRANSIT_DISTRICT  \
# count       6.977342e+06  6.959143e+06  6.959143e+06     157084.000000
# mean        7.304343e-01  1.004796e+06  2.070544e+05         13.598400
# std         6.752324e+00  2.174732e+04  3.153994e+04         12.471429
# min         0.000000e+00  1.110000e+02  1.110000e+02          1.000000
# 25%         0.000000e+00  9.916830e+05  1.843520e+05          3.000000
# 50%         0.000000e+00  1.004370e+06  2.059660e+05         11.000000
# 75%         0.000000e+00  1.016586e+06  2.351580e+05         30.000000
# max         9.700000e+01  1.067298e+06  7.250292e+06         34.000000
#
#            Latitude     Longitude
# count  6.959143e+06  6.959143e+06
# mean   4.073495e+01 -7.392583e+01
# std    8.647664e-02  7.842862e-02
# min    4.011271e+01 -7.751921e+01
# 25%    4.067261e+01 -7.397323e+01
# 50%    4.073196e+01 -7.392733e+01
# 75%    4.081212e+01 -7.388325e+01
# max    5.965727e+01 -7.368479e+01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983207 entries, 0 to 6983206
# Data columns (total 35 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   CMPLNT_NUM         int64
#  1   CMPLNT_FR_DT       object
#  2   CMPLNT_FR_TM       object
#  3   CMPLNT_TO_DT       object
#  4   CMPLNT_TO_TM       object
#  5   ADDR_PCT_CD        float64
#  6   RPT_DT             object
#  7   KY_CD              int64
#  8   OFNS_DESC          object
#  9   PD_CD              float64
#  10  PD_DESC            object
#  11  CRM_ATPT_CPTD_CD   object
#  12  LAW_CAT_CD         object
#  13  BORO_NM            object
#  14  LOC_OF_OCCUR_DESC  object
#  15  PREM_TYP_DESC      object
#  16  JURIS_DESC         object
#  17  JURISDICTION_CODE  float64
#  18  PARKS_NM           object
#  19  HADEVELOPT         object
#  20  HOUSING_PSA        object
#  21  X_COORD_CD         float64
#  22  Y_COORD_CD         float64
#  23  SUSP_AGE_GROUP     object
#  24  SUSP_RACE          object
#  25  SUSP_SEX           object
#  26  TRANSIT_DISTRICT   float64
#  27  Latitude           float64
#  28  Longitude          float64
#  29  Lat_Lon            object
#  30  PATROL_BORO        object
#  31  STATION_NAME       object
#  32  VIC_AGE_GROUP      object
#  33  VIC_RACE           object
#  34  VIC_SEX            object
# dtypes: float64(8), int64(2), object(25)
# memory usage: 1.8+ GB

# %%
df.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'JURISDICTION_CODE',
#        'PARKS_NM', 'HADEVELOPT', 'HOUSING_PSA', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT',
#        'Latitude', 'Longitude', 'Lat_Lon', 'PATROL_BORO', 'STATION_NAME',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %% [markdown]
# Renaming the columns

# %%
rename_columns = {
    "CMPLNT_NUM": "Complaint_ID",
    "CMPLNT_FR_DT": "Start_Date",
    "CMPLNT_FR_TM": "Start_Time",
    "CMPLNT_TO_DT": "End_Date",
    "CMPLNT_TO_TM": "End_Time",
    "RPT_DT": "Report_Date",
    "KY_CD": "Offense_Code",
    "OFNS_DESC": "Offense_Description",
    "PD_CD": "Precinct_Code",
    "PD_DESC": "Precinct_Description",
    "CRM_ATPT_CPTD_CD": "Crime_Status",
    "LAW_CAT_CD": "Offense_Level",
    "JURIS_DESC": "Jurisdiction",
    "BORO_NM": "Borough",
    "ADDR_PCT_CD": "Precinct",
    "LOC_OF_OCCUR_DESC": "Location_Type",
    "PREM_TYP_DESC": "Premises_Type",
    "PARKS_NM": "Park_Name",
    "HADEVELOPT": "Housing_Development",
    "HOUSING_PSA": "PSA_Code",
    "X_COORD_CD": "X_Coordinate",
    "Y_COORD_CD": "Y_Coordinate",
    "Latitude": "Lat",
    "Longitude": "Lon",
    "Lat_Lon": "Coordinates",
    "PATROL_BORO": "Patrol_Borough",
    "STATION_NAME": "Station_Name",
    "VIC_AGE_GROUP": "Victim_Age",
    "VIC_RACE": "Victim_Race",
    "VIC_SEX": "Victim_Gender",
    "SUSP_AGE_GROUP": "Suspect_Age",
    "SUSP_RACE": "Suspect_Race",
    "SUSP_SEX": "Suspect_Gender",
    "TRANSIT_DISTRICT": "Transit_District"
}


df.rename(columns=rename_columns, inplace=True)

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Start_Date', 'Start_Time', 'End_Date', 'End_Time',
#        'Precinct', 'Report_Date', 'Offense_Code', 'Offense_Description',
#        'Precinct_Code', 'Precinct_Description', 'Crime_Status',
#        'Offense_Level', 'Borough', 'Location_Type', 'Premises_Type',
#        'Jurisdiction', 'JURISDICTION_CODE', 'Park_Name', 'Housing_Development',
#        'PSA_Code', 'X_Coordinate', 'Y_Coordinate', 'Suspect_Age',
#        'Suspect_Race', 'Suspect_Gender', 'Transit_District', 'Lat', 'Lon',
#        'Coordinates', 'Patrol_Borough', 'Station_Name', 'Victim_Age',
#        'Victim_Race', 'Victim_Gender'],
#       dtype='object')

# %%
for column in df.columns:
    print(column,'have ',(df[column].isna().sum()*100/len(df)),' % missing values')
# Out:
# Complaint_ID have  0.0  % missing values
# Start_Date have  0.009379644624597266  % missing values
# Start_Time have  0.0006873632701994943  % missing values
# End_Date have  23.89125798504899  % missing values
# End_Time have  23.826144635265717  % missing values
# Precinct have  0.03101726756775218  % missing values
# Report_Date have  0.0  % missing values
# Offense_Code have  0.0  % missing values
# Offense_Description have  0.26957528253136415  % missing values
# Precinct_Code have  0.08398719957750071  % missing values
# Precinct_Description have  0.08398719957750071  % missing values
# Crime_Status have  0.00010024047690409292  % missing values
# Offense_Level have  0.0  % missing values
# Borough have  0.1560028221990269  % missing values
# Location_Type have  21.19358627060604  % missing values
# Premises_Type have  0.5689649469076314  % missing values
# Jurisdiction have  0.0  % missing values
# JURISDICTION_CODE have  0.08398719957750071  % missing values
# Park_Name have  99.6413109335009  % missing values
# Housing_Development have  95.04485546540437  % missing values
# PSA_Code have  92.31142654084292  % missing values
# X_Coordinate have  0.3445981194600131  % missing values
# Y_Coordinate have  0.3445981194600131  % missing values
# Suspect_Age have  67.41276608297592  % missing values
# Suspect_Race have  47.81516572543246  % missing values
# Suspect_Gender have  49.72423128800278  % missing values
# Transit_District have  97.75054641799964  % missing values
# Lat have  0.3445981194600131  % missing values
# Lon have  0.3445981194600131  % missing values
# Coordinates have  0.3445981194600131  % missing values
# Patrol_Borough have  0.09053147071252506  % missing values
# Station_Name have  97.75054641799964  % missing values
# Victim_Age have  23.46262970580709  % missing values
# Victim_Race have  0.0044105809837800885  % missing values
# Victim_Gender have  0.004396260915650933  % missing values

# %% [markdown]
# ## Part(1)

# %% [markdown]
# PSA(POLICE SeRVICE AREA) near New York City Housing Authority and housing is a part in psa

# %%
df['in_psa'] = df['PSA_Code'].notna().astype(int)

# %%
df['in_psa_housing'] = df.apply(
    lambda row: 1 if pd.notna(row['PSA_Code']) and pd.notna(row['Housing_Development']) else 0,
    axis=1
)

# %%
df['in_transport'] = df.apply(
    lambda row: 1 if pd.notna(row['Transit_District']) and pd.notna(row['Station_Name']) else 0,
    axis=1
)

# %%
df['in_park'] = df['Park_Name'].notna().astype(int)

# %%
df.drop(columns='Park_Name',inplace=True)

# %%
df.drop(columns=["PSA_Code","Housing_Development","Transit_District","Station_Name"],inplace=True)

# %% [markdown]
# we must elimninate the crimes that we dont have the location and we drop off the varibale indicating the same location

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Start_Date', 'Start_Time', 'End_Date', 'End_Time',
#        'Precinct', 'Report_Date', 'Offense_Code', 'Offense_Description',
#        'Precinct_Code', 'Precinct_Description', 'Crime_Status',
#        'Offense_Level', 'Borough', 'Location_Type', 'Premises_Type',
#        'Jurisdiction', 'JURISDICTION_CODE', 'X_Coordinate', 'Y_Coordinate',
#        'Suspect_Age', 'Suspect_Race', 'Suspect_Gender', 'Lat', 'Lon',
#        'Coordinates', 'Patrol_Borough', 'Victim_Age', 'Victim_Race',
#        'Victim_Gender', 'in_psa', 'in_psa_housing', 'in_transport', 'in_park'],
#       dtype='object')

# %%
df.drop(columns=['X_Coordinate','Y_Coordinate',"Coordinates"],inplace=True)

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Start_Date', 'Start_Time', 'End_Date', 'End_Time',
#        'Precinct', 'Report_Date', 'Offense_Code', 'Offense_Description',
#        'Precinct_Code', 'Precinct_Description', 'Crime_Status',
#        'Offense_Level', 'Borough', 'Location_Type', 'Premises_Type',
#        'Jurisdiction', 'JURISDICTION_CODE', 'Suspect_Age', 'Suspect_Race',
#        'Suspect_Gender', 'Lat', 'Lon', 'Patrol_Borough', 'Victim_Age',
#        'Victim_Race', 'Victim_Gender', 'in_psa', 'in_psa_housing',
#        'in_transport', 'in_park'],
#       dtype='object')

# %%
df = df[df['Lat'].notna()]
df = df[df['Lon'].notna()]

# %%
df
# Out:
#          Complaint_ID  Start_Date Start_Time    End_Date  End_Time  Precinct  \
# 0           700381962  05/28/2015   15:00:00         NaN       NaN      46.0
# 1           642234217  10/28/2013   13:50:00  10/28/2013  13:50:00     120.0
# 2           242465164  05/09/2012   20:50:00  05/09/2012  21:00:00      24.0
# 3           927207428  01/03/2014   13:30:00  01/03/2014  13:35:00     108.0
# 4           492142357  04/13/2016   00:00:00         NaN       NaN      40.0
# ...               ...         ...        ...         ...       ...       ...
# 6983199     120248300  09/11/2018   22:30:00  09/11/2018  22:48:00     110.0
# 6983200     180596560  01/15/2018   14:23:00  01/15/2018  14:23:00      47.0
# 6983201     142216265  08/07/2018   14:42:00  08/07/2018  14:44:00      78.0
# 6983202     225471008  12/02/2018   04:15:00  12/02/2018  04:17:00     109.0
# 6983204     146134182  08/03/2018   22:30:00  08/04/2018  06:30:00      41.0
#
#         Report_Date  Offense_Code             Offense_Description  \
# 0        06/01/2015           578                   HARRASSMENT 2
# 1        10/28/2013           351  CRIMINAL MISCHIEF & RELATED OF
# 2        05/09/2012           236               DANGEROUS WEAPONS
# 3        01/03/2014           109                   GRAND LARCENY
# 4        04/13/2016           351  CRIMINAL MISCHIEF & RELATED OF
# ...             ...           ...                             ...
# 6983199  09/11/2018           111   POSSESSION OF STOLEN PROPERTY
# 6983200  01/15/2018           341                   PETIT LARCENY
# 6983201  08/07/2018           344    ASSAULT 3 & RELATED OFFENSES
# 6983202  12/02/2018           344    ASSAULT 3 & RELATED OFFENSES
# 6983204  08/04/2018           121  CRIMINAL MISCHIEF & RELATED OF
#
#          Precinct_Code  ...        Lat        Lon             Patrol_Borough  \
# 0                638.0  ...  40.845868 -73.915888          PATROL BORO BRONX
# 1                259.0  ...  40.627061 -74.077149  PATROL BORO STATEN ISLAND
# 2                782.0  ...  40.800966 -73.969047      PATROL BORO MAN NORTH
# 3                409.0  ...  40.745242 -73.894253   PATROL BORO QUEENS NORTH
# 4                258.0  ...  40.810352 -73.924942          PATROL BORO BRONX
# ...                ...  ...        ...        ...                        ...
# 6983199          494.0  ...  40.741889 -73.859886   PATROL BORO QUEENS NORTH
# 6983200          338.0  ...  40.878054 -73.863244          PATROL BORO BRONX
# 6983201          101.0  ...  40.672202 -73.983786    PATROL BORO BKLYN SOUTH
# 6983202          101.0  ...  40.785050 -73.856852   PATROL BORO QUEENS NORTH
# 6983204          267.0  ...  40.814612 -73.903637          PATROL BORO BRONX
#
#         Victim_Age               Victim_Race Victim_Gender in_psa  \
# 0            25-44            WHITE HISPANIC             F      0
# 1            45-64                     WHITE             M      0
# 2              NaN                   UNKNOWN             E      0
# 3            45-64  ASIAN / PACIFIC ISLANDER             M      0
# 4          UNKNOWN                   UNKNOWN             E      0
# ...            ...                       ...           ...    ...
# 6983199    UNKNOWN                   UNKNOWN             E      0
# 6983200      45-64                     BLACK             F      0
# 6983201      18-24                     BLACK             M      0
# 6983202      25-44  ASIAN / PACIFIC ISLANDER             F      0
# 6983204      25-44            BLACK HISPANIC             F      0
#
#          in_psa_housing in_transport in_park
# 0                     0            0       0
# 1                     0            0       0
# 2                     0            0       0
# 3                     0            0       0
# 4                     0            0       0
# ...                 ...          ...     ...
# 6983199               0            0       0
# 6983200               0            0       0
# 6983201               0            0       1
# 6983202               0            0       0
# 6983204               0            0       0
#
# [6959143 rows x 31 columns]

# %%
df['Start_Datetime'] = pd.to_datetime(
    df['Start_Date'] + ' ' + df['Start_Time'], 
    format="%m/%d/%Y %H:%M:%S", 
    errors='coerce'  # Handle invalid dates gracefully
)
df['End_Datetime'] = pd.to_datetime(
    df['End_Date'] + ' ' + df['End_Time'], 
    format="%m/%d/%Y %H:%M:%S", 
    errors='coerce'
)

# %%
df['Duration_Hours'] = (df['End_Datetime'] - df['Start_Datetime']).dt.total_seconds() / 3600

df['Is_Multi_Day'] = df['Duration_Hours'] > 24

max_gap = df['Duration_Hours'].max()

print(f"Maximum gap in hours: {max_gap}")
# Out:
# Maximum gap in hours: 959050.0

# %%
df['Is_Multi_Day'].value_counts()
# Out:
# Is_Multi_Day
# False    6381164
# True      577979
# Name: count, dtype: int64

# %%
df.drop(columns=[ 'Start_Date', 'Start_Time', 'End_Date', 'End_Time'],inplace=True)

# %%
df=df[df['Start_Datetime'].notna()]

# %%
df['Year'] = df['Start_Datetime'].dt.year
df['Month'] = df['Start_Datetime'].dt.month
df['Day'] = df['Start_Datetime'].dt.day
df['DayOfWeek'] = df['Start_Datetime'].dt.dayofweek
df['Hour'] = df['Start_Datetime'].dt.hour
df['Is_Weekend'] = df['Start_Datetime'].dt.dayofweek >= 5
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\435837282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Start_Datetime'].dt.year
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\435837282.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Start_Datetime'].dt.month
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\435837282.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Day'] = df['Start_Datetime'].dt.day
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\435837282.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DayOfWeek'] = df['Start_Datetime'].dt.dayofweek
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\435837282.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df['Start_Datetime'].dt.hour
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\435837282.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Is_Weekend'] = df['Start_Datetime'].dt.dayofweek >= 5

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Precinct', 'Report_Date', 'Offense_Code',
#        'Offense_Description', 'Precinct_Code', 'Precinct_Description',
#        'Crime_Status', 'Offense_Level', 'Borough', 'Location_Type',
#        'Premises_Type', 'Jurisdiction', 'JURISDICTION_CODE', 'Suspect_Age',
#        'Suspect_Race', 'Suspect_Gender', 'Lat', 'Lon', 'Patrol_Borough',
#        'Victim_Age', 'Victim_Race', 'Victim_Gender', 'in_psa',
#        'in_psa_housing', 'in_transport', 'in_park', 'Start_Datetime',
#        'End_Datetime', 'Duration_Hours', 'Is_Multi_Day', 'Year', 'Month',
#        'Day', 'DayOfWeek', 'Hour', 'Is_Weekend'],
#       dtype='object')

# %%
df['Precinct'].value_counts()
# Out:
# Precinct
#  75.0     224101
#  43.0     180043
#  44.0     174593
#  40.0     167663
#  14.0     159982
#            ...
#  121.0     41909
#  76.0      39097
#  100.0     36678
#  22.0       5517
# -99.0        750
# Name: count, Length: 78, dtype: int64

# %%
negative_precincts = df[df['Precinct'] < 0]
len(negative_precincts)
# Out:
# 750

# %% [markdown]
# so it is a misstype

# %%
df['Precinct'] = df['Precinct'].abs()
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\2071024195.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Precinct'] = df['Precinct'].abs()

# %%
for column in df.columns:
    print(column,'have ',(df[column].isna().sum()*100/len(df)),' % missing values')
# Out:
# Complaint_ID have  0.0  % missing values
# Precinct have  0.019099473478246937  % missing values
# Report_Date have  0.0  % missing values
# Offense_Code have  0.0  % missing values
# Offense_Description have  0.2688297598826841  % missing values
# Precinct_Code have  0.07749011361528027  % missing values
# Precinct_Description have  0.07749011361528027  % missing values
# Crime_Status have  0.00010059918310589056  % missing values
# Offense_Level have  0.0  % missing values
# Borough have  0.1497203270853097  % missing values
# Location_Type have  21.203433536347276  % missing values
# Premises_Type have  0.5557530014125562  % missing values
# Jurisdiction have  0.0  % missing values
# JURISDICTION_CODE have  0.07749011361528027  % missing values
# Suspect_Age have  67.4045999982467  % missing values
# Suspect_Race have  47.79715813056251  % missing values
# Suspect_Gender have  49.700480303614086  % missing values
# Lat have  0.0  % missing values
# Lon have  0.0  % missing values
# Patrol_Borough have  0.07861107594131733  % missing values
# Victim_Age have  23.47385649986412  % missing values
# Victim_Race have  0.004426364056659185  % missing values
# Victim_Gender have  0.004411992744786914  % missing values
# in_psa have  0.0  % missing values
# in_psa_housing have  0.0  % missing values
# in_transport have  0.0  % missing values
# in_park have  0.0  % missing values
# Start_Datetime have  0.0  % missing values
# End_Datetime have  23.897609001729876  % missing values
# Duration_Hours have  23.897609001729876  % missing values
# Is_Multi_Day have  0.0  % missing values
# Year have  0.0  % missing values
# Month have  0.0  % missing values
# Day have  0.0  % missing values
# DayOfWeek have  0.0  % missing values
# Hour have  0.0  % missing values
# Is_Weekend have  0.0  % missing values

# %%
df['Offense_Description'].value_counts()
# Out:
# Offense_Description
# PETIT LARCENY                      1161706
# HARRASSMENT 2                       877795
# ASSAULT 3 & RELATED OFFENSES        729340
# CRIMINAL MISCHIEF & RELATED OF      697031
# GRAND LARCENY                       604781
#                                     ...
# FELONY SEX CRIMES                       10
# ABORTION                                 7
# OFFENSES AGAINST MARRIAGE UNCL           4
# KIDNAPPING AND RELATED OFFENSES          3
# UNDER THE INFLUENCE OF DRUGS             3
# Name: count, Length: 71, dtype: int64

# %%
prop = ['BURGLARY', 'PETIT LARCENY', 'GRAND LARCENY', 'ROBBERY', 'THEFT-FRAUD', 
        'GRAND LARCENY OF MOTOR VEHICLE', 'FORGERY', 'JOSTLING', 'ARSON',
        'PETIT LARCENY OF MOTOR VEHICLE', 'OTHER OFFENSES RELATED TO THEF',
        "BURGLAR'S TOOLS", 'FRAUDS', 'POSSESSION OF STOLEN PROPERTY',
        'CRIMINAL MISCHIEF & RELATED OF', 'OFFENSES INVOLVING FRAUD',
        'FRAUDULENT ACCOSTING', 'THEFT OF SERVICES']

sexual = ['SEX CRIMES', 'HARRASSMENT 2', 'RAPE', 'PROSTITUTION & RELATED OFFENSES',
          'FELONY SEX CRIMES', 'LOITERING/DEVIATE SEX']

drug_alch = ['DANGEROUS DRUGS', 'INTOXICATED & IMPAIRED DRIVING',
             'ALCOHOLIC BEVERAGE CONTROL LAW', 'INTOXICATED/IMPAIRED DRIVING',
             'UNDER THE INFLUENCE OF DRUGS', 'LOITERING FOR DRUG PURPOSES']

personal = ['ASSAULT 3 & RELATED OFFENSES', 'FELONY ASSAULT',
            'OFFENSES AGAINST THE PERSON', 'HOMICIDE-NEGLIGENT,UNCLASSIFIE',
            'HOMICIDE-NEGLIGENT-VEHICLE', 'KIDNAPPING & RELATED OFFENSES',
            'ENDAN WELFARE INCOMP', 'OFFENSES RELATED TO CHILDREN',
            'CHILD ABANDONMENT/NON SUPPORT', 'KIDNAPPING', 'DANGEROUS WEAPONS',
            'UNLAWFUL POSS. WEAP. ON SCHOOL']

admin = ['OFF. AGNST PUB ORD SENSBLTY &', 'CRIMINAL TRESPASS', 
         'VEHICLE AND TRAFFIC LAWS', 'OFFENSES AGAINST PUBLIC ADMINI',
         'ADMINISTRATIVE CODE', 'OFFENSES AGAINST PUBLIC SAFETY',
         'LOITERING/GAMBLING (CARDS, DIC', 'DISORDERLY CONDUCT',
         'NEW YORK CITY HEALTH CODE', 'DISRUPTION OF A RELIGIOUS SERV',
         'LOITERING', 'ADMINISTRATIVE CODES']

other = ['MISCELLANEOUS PENAL LAW', 'OFFENSES AGAINST MARRIAGE UNCL',
         'OTHER STATE LAWS (NON PENAL LAW)', 'FORTUNE TELLING',
         'NYS LAWS-UNCLASSIFIED VIOLATION', 'LOITERING/GAMBLING (CARDS, DIC',
         'GAMBLING', 'OTHER STATE LAWS (NON PENAL LA', 'OTHER STATE LAWS',
         'ANTICIPATORY OFFENSES', 'ESCAPE 3', 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED',
         'NYS LAWS-UNCLASSIFIED FELONY', 'UNAUTHORIZED USE OF A VEHICLE', 'OTHER']

# %%
conditions = [
    df['Offense_Description'].isin(prop),
    df['Offense_Description'].isin(sexual),
    df['Offense_Description'].isin(drug_alch),
    df['Offense_Description'].isin(personal),
    df['Offense_Description'].isin(admin)
]
categories = ['PROPERTY_RELATED', 'SEXUAL_RELATED', 'DRUGS/ALCOHOL_RELATED', 'PERSONAL_RELATED', 'ADMINISTRATIVE_RELATED']
df['Offense_Description'] = np.select(conditions, categories, default='OTHER')
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\1734916441.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Offense_Description'] = np.select(conditions, categories, default='OTHER')

# %%
df['Patrol_Borough'].value_counts()
# Out:
# Patrol_Borough
# PATROL BORO BRONX            1509089
# PATROL BORO BKLYN SOUTH      1036404
# PATROL BORO BKLYN NORTH      1031280
# PATROL BORO MAN SOUTH         845712
# PATROL BORO MAN NORTH         827402
# PATROL BORO QUEENS NORTH      710729
# PATROL BORO QUEENS SOUTH      666286
# PATROL BORO STATEN ISLAND     325935
# Name: count, dtype: int64

# %%
df['Patrol_Borough'] = df['Patrol_Borough'].fillna("Unknown")
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\301418187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Patrol_Borough'] = df['Patrol_Borough'].fillna("Unknown")

# %%
df['Borough'] = df['Borough'].fillna("UNKNOWN")
df['Precinct'] = df['Precinct'].fillna(0)
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\124913090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Borough'] = df['Borough'].fillna("UNKNOWN")
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\124913090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Precinct'] = df['Precinct'].fillna(0)

# %%
df= df.dropna(subset=['Crime_Status'])

# %%
df.fillna({'Location_Type':'UNKNOWN'}, inplace=True)

# %%
valid_age = ['UNKNOWN', '25-44', '<18', '45-64', '65+', '18-24']
df.loc[~df['Suspect_Age'].isin(valid_age),'Suspect_Age'] = 'UNKNOWN'
df.loc[~df['Victim_Age'].isin(valid_age),'Victim_Age'] = 'UNKNOWN'

# %%
df['Suspect_Race'] = df['Suspect_Race'].fillna('UNKNOWN')
df['Victim_Race'] = df['Victim_Race'].fillna('UNKNOWN')

df['Suspect_Gender'] = df['Suspect_Gender'].fillna('U')
df['Victim_Gender'] = df['Victim_Gender'].fillna('U')

# %%
df['End_Datetime'] = df['End_Datetime'].fillna(df['Start_Datetime'])
df['Duration_Hours'] = df['Duration_Hours'].fillna(0)

# %%
df.dropna(inplace=True)

# %%
len(df)
# Out:
# 6919629

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Precinct', 'Report_Date', 'Offense_Code',
#        'Offense_Description', 'Precinct_Code', 'Precinct_Description',
#        'Crime_Status', 'Offense_Level', 'Borough', 'Location_Type',
#        'Premises_Type', 'Jurisdiction', 'JURISDICTION_CODE', 'Suspect_Age',
#        'Suspect_Race', 'Suspect_Gender', 'Lat', 'Lon', 'Patrol_Borough',
#        'Victim_Age', 'Victim_Race', 'Victim_Gender', 'in_psa',
#        'in_psa_housing', 'in_transport', 'in_park', 'Start_Datetime',
#        'End_Datetime', 'Duration_Hours', 'Is_Multi_Day', 'Year', 'Month',
#        'Day', 'DayOfWeek', 'Hour', 'Is_Weekend'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
offense_level_counts = df['Offense_Level'].value_counts()
colors = ['#87CEEB', '#FF9999', '#99CC99']

plt.figure(figsize=(8, 8))
offense_level_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    legend=False
)
plt.title('Distribution of Offense Levels', fontsize=14)
plt.tight_layout()
plt.show()

# %%
valid_age = ['UNKNOWN', '25-44', '<18', '45-64', '65+', '18-24']
colors = ['#D3D3D3', '#87CEEB', '#FF9999', '#FFCC99', '#99CC99', '#9999FF']  # Define a color for each category

suspect_age_counts = df['Suspect_Age'].value_counts().reindex(valid_age, fill_value=0)
victim_age_counts = df['Victim_Age'].value_counts().reindex(valid_age, fill_value=0)

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

suspect_age_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[0],
    legend=False
)
axes[0].set_ylabel('')
axes[0].set_title('Distribution of Suspect Age')

victim_age_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[1],
    legend=False
)
axes[1].set_ylabel('')
axes[1].set_title('Distribution of Victim Age')

plt.tight_layout()
plt.show()

# %%
valid_age = ['25-44', '<18', '45-64', '65+', '18-24']
colors = ['#87CEEB', '#FF9999', '#FFCC99', '#99CC99', '#9999FF']  

suspect_age_counts = df['Suspect_Age'].value_counts().reindex(valid_age, fill_value=0)
victim_age_counts = df['Victim_Age'].value_counts().reindex(valid_age, fill_value=0)

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

suspect_age_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[0],
    legend=False
)
axes[0].set_ylabel('')
axes[0].set_title('Distribution of Suspect Age (Excluding UNKNOWN)')

victim_age_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[1],
    legend=False
)
axes[1].set_ylabel('')
axes[1].set_title('Distribution of Victim Age (Excluding UNKNOWN)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

valid_race = ['BLACK', 'WHITE', 'BLACK HISPANIC', 'WHITE HISPANIC', 
              'ASIAN / PACIFIC ISLANDER', 'AMERICAN INDIAN/ALASKAN NATIVE', 'OTHER']
colors = ['#87CEEB', '#FF9999', '#FFCC99', '#99CC99', '#9999FF', '#FFC0CB', '#FFB6C1']  # Colors for each race

suspect_race_counts = df['Suspect_Race'].value_counts().reindex(valid_race, fill_value=0)
victim_race_counts = df['Victim_Race'].value_counts().reindex(valid_race, fill_value=0)

fig, axes = plt.subplots(1, 2, figsize=(12,6))

suspect_race_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[0],
    legend=False
)
axes[0].set_ylabel('')
axes[0].set_title('Distribution of Suspect Race (Excluding UNKNOWN)')

victim_race_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[1],
    legend=False
)
axes[1].set_ylabel('')
axes[1].set_title('Distribution of Victim Race (Excluding UNKNOWN)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

valid_gender = ['M', 'F']
colors = ['#87CEEB', '#FF9999']

suspect_gender_counts = df['Suspect_Gender'].value_counts().reindex(valid_gender, fill_value=0)
victim_gender_counts = df['Victim_Gender'].value_counts().reindex(valid_gender, fill_value=0)

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

suspect_gender_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[0],
    legend=False
)
axes[0].set_ylabel('')
axes[0].set_title('Distribution of Suspect Gender (Excluding UNKNOWN)')

victim_gender_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=axes[1],
    legend=False
)
axes[1].set_ylabel('')
axes[1].set_title('Distribution of Victim Gender (Excluding UNKNOWN)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

valid_offenses = ['PROPERTY_RELATED', 'SEXUAL_RELATED', 'DRUGS/ALCOHOL_RELATED', 'PERSONAL_RELATED', 'ADMINISTRATIVE_RELATED','OTHER']
colors = ['#87CEEB', '#FF9999', '#FFCC99', '#99CC99', '#9999FF', '#FFC0CB']  
offense_counts = df['Offense_Description'].value_counts().reindex(valid_offenses, fill_value=0)

fig, ax = plt.subplots(figsize=(8, 8))

offense_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=ax,
    legend=False
)

ax.set_ylabel('')
ax.set_title('Distribution of Offense Description')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

valid_offenses = ['PROPERTY_RELATED', 'SEXUAL_RELATED', 'DRUGS/ALCOHOL_RELATED', 'PERSONAL_RELATED', 'ADMINISTRATIVE_RELATED']
colors = ['#87CEEB', '#FF9999', '#FFCC99', '#99CC99', '#9999FF', '#FFC0CB']  

offense_counts = df['Offense_Description'].value_counts().reindex(valid_offenses, fill_value=0)

fig, ax = plt.subplots(figsize=(8, 8))

offense_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    ax=ax,
    legend=False
)

ax.set_ylabel('')
ax.set_title('Distribution of Offense Description (Excluding OTHER)')

plt.tight_layout()
plt.show()

# %%
df['Suspect_Age'].unique()
# Out:
# array(['25-44', 'UNKNOWN', '45-64', '<18', '18-24', '65+'], dtype=object)

# %%
df['Suspect_Race'].unique()
# Out:
# array(['BLACK', 'UNKNOWN', 'BLACK HISPANIC', 'WHITE', 'WHITE HISPANIC',
#        'ASIAN / PACIFIC ISLANDER', 'AMERICAN INDIAN/ALASKAN NATIVE',
#        'OTHER'], dtype=object)

# %%
df['Suspect_Gender'].unique()
# Out:
# array(['M', 'U', 'F'], dtype=object)

# %%
import seaborn as sns

# %%
features = ['in_psa', 'in_transport', 'in_park']

percentages = {feature: (df[feature].sum() / df[feature].count()) * 100 for feature in features}

percentages_df = pd.DataFrame(list(percentages.items()), columns=['Feature', 'Percentage'])

plt.figure(figsize=(8, 6))
sns.barplot(x='Feature', y='Percentage', data=percentages_df, palette='viridis')

plt.title('Percentage of Crimes for Each Feature', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=12)
plt.xlabel('Feature', fontsize=12)
plt.ylim(0, 100) 

for index, row in percentages_df.iterrows():
    plt.text(index, row['Percentage'] + 2, f"{row['Percentage']:.1f}%", ha='center', fontsize=11)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\amenm\AppData\Local\Temp\ipykernel_17804\1166519526.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Feature', y='Percentage', data=percentages_df, palette='viridis')

# %%
total_in_psa = df['in_psa'].sum()
in_psa_housing=df['in_psa_housing'].sum()
percentage=(in_psa_housing/total_in_psa)*100
plt.figure(figsize=(6, 6))
plt.pie(
    [percentage, 100 - percentage],
    labels=['Yes', 'No'],
    autopct='%1.1f%%',
    startangle=90,
    colors=['#FF9999', '#87CEEB']
)
plt.title('Percentage of the crimes in Housing Area within Police Service Area.')
plt.show()

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Precinct', 'Report_Date', 'Offense_Code',
#        'Offense_Description', 'Precinct_Code', 'Precinct_Description',
#        'Crime_Status', 'Offense_Level', 'Borough', 'Location_Type',
#        'Premises_Type', 'Jurisdiction', 'JURISDICTION_CODE', 'Suspect_Age',
#        'Suspect_Race', 'Suspect_Gender', 'Lat', 'Lon', 'Patrol_Borough',
#        'Victim_Age', 'Victim_Race', 'Victim_Gender', 'in_psa',
#        'in_psa_housing', 'in_transport', 'in_park', 'Start_Datetime',
#        'End_Datetime', 'Duration_Hours', 'Is_Multi_Day', 'Year', 'Month',
#        'Day', 'DayOfWeek', 'Hour', 'Is_Weekend'],
#       dtype='object')

# %%
df['Borough'].unique()
# Out:
# array(['BRONX', 'STATEN ISLAND', 'MANHATTAN', 'QUEENS', 'BROOKLYN',
#        'UNKNOWN'], dtype=object)

# %%
borough_counts = df[df['Borough'] != 'Unknown']['Borough'].value_counts()

colors = ['#FF9999', '#66B2FF', '#99FF99', '#FFCC99', '#C299FF']

plt.figure(figsize=(8, 8))
borough_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    legend=False
)
plt.title('Distribution of Crimes (Excluding Unknown)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

filtered_data = df[
    (df['Borough'] != 'Unknown') &
    (df['Offense_Description'] != 'OTHER')
]
crime_borough_distribution = (
    filtered_data.groupby(['Borough', 'Offense_Description'])
    .size()
    .unstack(fill_value=0)
)

crime_borough_percentages = crime_borough_distribution.div(crime_borough_distribution.sum(axis=1), axis=0) * 100

fig, ax = plt.subplots(figsize=(16, 10))  
crime_borough_percentages.plot(
    kind='bar',
    figsize=(16, 10),
    ax=ax,
    width=0.8,
    colormap='tab10'
)


for i, borough in enumerate(crime_borough_percentages.index):
    for j, offense_type in enumerate(crime_borough_percentages.columns):
        percentage = crime_borough_percentages.loc[borough, offense_type]
        if percentage > 0:  
            ax.text(i + (j - 2) * 0.18, percentage + 1, f"{percentage:.1f}%", ha='center', fontsize=11, color='black')

ax.set_title('Crime Type Distribution by Borough (Percentage)', fontsize=20, pad=20)
ax.set_xlabel('Borough', fontsize=16, labelpad=10)
ax.set_ylabel('Percentage (%)', fontsize=16, labelpad=10)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.legend(title='Offense Description', title_fontsize=14, fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6919629 entries, 0 to 6983204
# Data columns (total 37 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Complaint_ID          int64
#  1   Precinct              float64
#  2   Report_Date           object
#  3   Offense_Code          int64
#  4   Offense_Description   object
#  5   Precinct_Code         float64
#  6   Precinct_Description  object
#  7   Crime_Status          object
#  8   Offense_Level         object
#  9   Borough               object
#  10  Location_Type         object
#  11  Premises_Type         object
#  12  Jurisdiction          object
#  13  JURISDICTION_CODE     float64
#  14  Suspect_Age           object
#  15  Suspect_Race          object
#  16  Suspect_Gender        object
#  17  Lat                   float64
#  18  Lon                   float64
#  19  Patrol_Borough        object
#  20  Victim_Age            object
#  21  Victim_Race           object
#  22  Victim_Gender         object
#  23  in_psa                int64
#  24  in_psa_housing        int64
#  25  in_transport          int64
#  26  in_park               int64
#  27  Start_Datetime        datetime64[ns]
#  28  End_Datetime          datetime64[ns]
#  29  Duration_Hours        float64
#  30  Is_Multi_Day          bool
#  31  Year                  int32
#  32  Month                 int32
#  33  Day                   int32
#  34  DayOfWeek             int32
#  35  Hour                  int32
#  36  Is_Weekend            bool
# dtypes: bool(2), datetime64[ns](2), float64(6), int32(5), int64(6), object(16)
# memory usage: 1.7+ GB

# %%
crime_status_counts = df['Crime_Status'].value_counts()

colors = ['#87CEEB', '#FF9999'] 

plt.figure(figsize=(8, 8))
crime_status_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    legend=False
)

plt.title('Distribution of Crime Status', fontsize=14)

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Precinct', 'Report_Date', 'Offense_Code',
#        'Offense_Description', 'Precinct_Code', 'Precinct_Description',
#        'Crime_Status', 'Offense_Level', 'Borough', 'Location_Type',
#        'Premises_Type', 'Jurisdiction', 'JURISDICTION_CODE', 'Suspect_Age',
#        'Suspect_Race', 'Suspect_Gender', 'Lat', 'Lon', 'Patrol_Borough',
#        'Victim_Age', 'Victim_Race', 'Victim_Gender', 'in_psa',
#        'in_psa_housing', 'in_transport', 'in_park', 'Start_Datetime',
#        'End_Datetime', 'Duration_Hours', 'Is_Multi_Day', 'Year', 'Month',
#        'Day', 'DayOfWeek', 'Hour', 'Is_Weekend'],
#       dtype='object')

# %%
multi_day_counts = df['Is_Multi_Day'].value_counts()
colors = ['#87CEEB', '#FF9999']

plt.figure(figsize=(8, 8))
multi_day_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    legend=False
)

plt.title('Distribution of Multi-Day Crimes', fontsize=14)
plt.tight_layout()
plt.show()

# %%
crimes_per_month = df.groupby('Month').size()

plt.figure(figsize=(10, 6))
crimes_per_month.plot(kind='line', marker='o', color='#87CEEB')
plt.title('Number of Crimes per Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
crimes_per_day = df.groupby('Day').size()

plt.figure(figsize=(10, 6))
crimes_per_day.plot(kind='line', marker='o', color='#FF9999')
plt.title('Number of Crimes per Day', fontsize=14)
plt.xlabel('Day', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
crimes_per_hour = df.groupby('Hour').size()

plt.figure(figsize=(10, 6))
crimes_per_hour.plot(kind='line', marker='o', color='#99CC99')
plt.title('Number of Crimes per Hour', fontsize=14)
plt.xlabel('Hour', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
crimes_per_year = df.groupby('Year').size()

plt.figure(figsize=(10, 6))
crimes_per_year.plot(kind='line', marker='o', color='#FFCC99')
plt.title('Crime Evolution per Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Complaint_ID', 'Precinct', 'Report_Date', 'Offense_Code',
#        'Offense_Description', 'Precinct_Code', 'Precinct_Description',
#        'Crime_Status', 'Offense_Level', 'Borough', 'Location_Type',
#        'Premises_Type', 'Jurisdiction', 'JURISDICTION_CODE', 'Suspect_Age',
#        'Suspect_Race', 'Suspect_Gender', 'Lat', 'Lon', 'Patrol_Borough',
#        'Victim_Age', 'Victim_Race', 'Victim_Gender', 'in_psa',
#        'in_psa_housing', 'in_transport', 'in_park', 'Start_Datetime',
#        'End_Datetime', 'Duration_Hours', 'Is_Multi_Day', 'Year', 'Month',
#        'Day', 'DayOfWeek', 'Hour', 'Is_Weekend'],
#       dtype='object')

# %%
df.drop(columns='Report_Date',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6919629 entries, 0 to 6983204
# Data columns (total 36 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Complaint_ID          int64
#  1   Precinct              float64
#  2   Offense_Code          int64
#  3   Offense_Description   object
#  4   Precinct_Code         float64
#  5   Precinct_Description  object
#  6   Crime_Status          object
#  7   Offense_Level         object
#  8   Borough               object
#  9   Location_Type         object
#  10  Premises_Type         object
#  11  Jurisdiction          object
#  12  JURISDICTION_CODE     float64
#  13  Suspect_Age           object
#  14  Suspect_Race          object
#  15  Suspect_Gender        object
#  16  Lat                   float64
#  17  Lon                   float64
#  18  Patrol_Borough        object
#  19  Victim_Age            object
#  20  Victim_Race           object
#  21  Victim_Gender         object
#  22  in_psa                int64
#  23  in_psa_housing        int64
#  24  in_transport          int64
#  25  in_park               int64
#  26  Start_Datetime        datetime64[ns]
#  27  End_Datetime          datetime64[ns]
#  28  Duration_Hours        float64
#  29  Is_Multi_Day          bool
#  30  Year                  int32
#  31  Month                 int32
#  32  Day                   int32
#  33  DayOfWeek             int32
#  34  Hour                  int32
#  35  Is_Weekend            bool
# dtypes: bool(2), datetime64[ns](2), float64(6), int32(5), int64(6), object(15)
# memory usage: 1.7+ GB

# %%
df['Location_Type'].value_counts()
# Out:
# Location_Type
# INSIDE         3509416
# FRONT OF       1607357
# UNKNOWN        1469993
# OPPOSITE OF     184881
# REAR OF         147982
# Name: count, dtype: int64

# %%
binary_columns = ['in_psa', 'in_psa_housing', 'in_transport', 'in_park']
df[binary_columns] = df[binary_columns].astype(bool)

# %%
columns_to_convert = ['Precinct', 'Precinct_Code', 'JURISDICTION_CODE']
df[columns_to_convert] = df[columns_to_convert].astype(int)

# %%
categorical_columns = [
    'Precinct_Description', 'Crime_Status', 'Offense_Level', 'Borough',
    'Location_Type', 'Suspect_Age', 'Suspect_Race', 'Suspect_Gender',
    'Patrol_Borough', 'Victim_Age', 'Victim_Race', 'Victim_Gender','Offense_Description'
]
df[categorical_columns] = df[categorical_columns].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6919629 entries, 0 to 6983204
# Data columns (total 36 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Complaint_ID          int64
#  1   Precinct              int64
#  2   Offense_Code          int64
#  3   Offense_Description   category
#  4   Precinct_Code         int64
#  5   Precinct_Description  category
#  6   Crime_Status          category
#  7   Offense_Level         category
#  8   Borough               category
#  9   Location_Type         category
#  10  Premises_Type         object
#  11  Jurisdiction          object
#  12  JURISDICTION_CODE     int64
#  13  Suspect_Age           category
#  14  Suspect_Race          category
#  15  Suspect_Gender        category
#  16  Lat                   float64
#  17  Lon                   float64
#  18  Patrol_Borough        category
#  19  Victim_Age            category
#  20  Victim_Race           category
#  21  Victim_Gender         category
#  22  in_psa                bool
#  23  in_psa_housing        bool
#  24  in_transport          bool
#  25  in_park               bool
#  26  Start_Datetime        datetime64[ns]
#  27  End_Datetime          datetime64[ns]
#  28  Duration_Hours        float64
#  29  Is_Multi_Day          bool
#  30  Year                  int32
#  31  Month                 int32
#  32  Day                   int32
#  33  DayOfWeek             int32
#  34  Hour                  int32
#  35  Is_Weekend            bool
# dtypes: bool(6), category(13), datetime64[ns](2), float64(3), int32(5), int64(5), object(2)
# memory usage: 950.3+ MB

# %%
for column in df.columns:
    print(column,'have ',(df[column].isna().sum()*100/len(df)),' % missing values')
# Out:
# Complaint_ID have  0.0  % missing values
# Precinct have  0.0  % missing values
# Offense_Code have  0.0  % missing values
# Offense_Description have  0.0  % missing values
# Precinct_Code have  0.0  % missing values
# Precinct_Description have  0.0  % missing values
# Crime_Status have  0.0  % missing values
# Offense_Level have  0.0  % missing values
# Borough have  0.0  % missing values
# Location_Type have  0.0  % missing values
# Premises_Type have  0.0  % missing values
# Jurisdiction have  0.0  % missing values
# JURISDICTION_CODE have  0.0  % missing values
# Suspect_Age have  0.0  % missing values
# Suspect_Race have  0.0  % missing values
# Suspect_Gender have  0.0  % missing values
# Lat have  0.0  % missing values
# Lon have  0.0  % missing values
# Patrol_Borough have  0.0  % missing values
# Victim_Age have  0.0  % missing values
# Victim_Race have  0.0  % missing values
# Victim_Gender have  0.0  % missing values
# in_psa have  0.0  % missing values
# in_psa_housing have  0.0  % missing values
# in_transport have  0.0  % missing values
# in_park have  0.0  % missing values
# Start_Datetime have  0.0  % missing values
# End_Datetime have  0.0  % missing values
# Duration_Hours have  0.0  % missing values
# Is_Multi_Day have  0.0  % missing values
# Year have  0.0  % missing values
# Month have  0.0  % missing values
# Day have  0.0  % missing values
# DayOfWeek have  0.0  % missing values
# Hour have  0.0  % missing values
# Is_Weekend have  0.0  % missing values

# %%
df.to_csv('NYC_Cleaned_Optimized.csv', index=False)
